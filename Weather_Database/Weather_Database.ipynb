# %%
# Import the dependancies
import json
from config import weather_api_key
import requests
import numpy as np
import random
from citipy import citipy 
import pandas as pd

# Starting URL for Weather Map API Call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs=zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lats_lngs)
print(coordinates)
# Out:
# [(66.74946692636982, 150.3024243749453), (-71.3548967742565, -4.387349770012008), (-76.34212721190467, 44.51530535188891), (-18.779966141899322, 73.97785556896417), (30.650370067547883, 9.713123124291599), (-80.01237254796654, -65.32008443932776), (-28.44228352970805, -174.90406247472677), (-82.2564013681294, -160.86892148464722), (-61.88562651446631, 58.24661894919282), (-16.987115096143484, 167.17215358242407), (73.1580509895278, -66.77661159483507), (-88.40332418481128, -143.7742473309837), (-21.181807939718382, -37.95908488669298), (51.00903435602174, -126.28074443289016), (-63.74933236487665, -61.022418061216214), (-27.275820327800538, -155.48329202976288), (20.779494525954178, 109.17104176032473), (41.445085066967835, 11.49656858684034), (2.032708597326078, 81.78123745906072), (31.185323820959695, -26.166267550116658), (-44.39221473074198, 21.210804222906773), (-17.723297539951943, -163.54029351985787), (-89.43820528440249, 178.6781109609393), (-6.919414980767158, 0.34099621978552364), (-28.858093317444755, 32.0527277590983), (-83.62916497154825, 158.72862843804847), (-71.27984981955645, 68.38723553885586), (-17.536032898834677, 13.468091050151088), (-76.91373905383648, 158.8340061467605), (-60.79184880562782, 28.13227844532844), (17.78938621086037, 69.32975814640704), (34.92310068729597, 34.89498612612391), (-35.90695645243812, 114.48380262133782), (-18.520706273225755, 77.80489038037791), (-52.21904923240097, 166.14540080311502), (-40.40124844069782, 151.7878631789144), (80.66085560944279, -99.31223474182887), (55.628192490172154, 149.82018150332067), (26.59845310163236, 120.36849598984855), (-78.31783424103989, 79.4605049886037), (-1.9990921312006549, 130.1920491930332), (-10.159875128377948, 20.862766226735317), (-2.6497632984399644, 24.594304097283327), (-18.364223157610397, 100.80324709670725), (-22.63119501108234, 3.514283443138254), (-46.97196121250721, -143.88586962569778), (-3.860485483212301, 164.7188236596955), (79.1556639674867, -66.1357361050494), (-70.4770322133403, -96.96724770221546), (-9.517443420210824, -143.3553247863129), (-60.720219235307596, 57.650181071118425), (5.730708195970379, -103.87146118939042), (27.142305857807614, 45.56071890278949), (-30.340804325684935, -122.44379375010567), (-78.38932177630244, -109.44137994790772), (3.1596632008446193, -119.96498394971664), (52.999278344348085, 95.68806696834628), (14.980978847824986, 61.478754055991175), (-77.03285926184783, 174.28590855371027), (-89.19145619237266, -26.619815787429843), (-30.363998876487834, -95.40225569302658), (41.038649598067394, -179.4182769054627), (-33.86091236525303, 170.43580415934093), (61.1683723916625, -28.892719280243625), (55.763636510251615, -135.1072319377073), (-49.33857723380072, 5.71931454394192), (21.476956842681588, 69.18315360247135), (17.602915483104994, 122.52219551129139), (48.023603082119195, -146.02385256731424), (20.276274133262007, 133.734707020084), (73.06953222150236, -6.285651957349103), (6.4620521917595966, -25.438963221240044), (-69.15277881411207, 135.38642628606777), (-73.31484120116063, -46.837010735230905), (-51.778271486061314, -100.90498503314055), (19.915120501634476, 99.26939734727927), (-72.74716580935832, -164.03160793360396), (35.29076111921228, 15.031169909439228), (-45.16467034876915, 13.198604234556228), (42.687773217908926, 141.69030930260647), (54.422127200095645, -103.76412503608564), (-32.836129778472014, 108.59761610817878), (35.678080299914754, 19.549689978326995), (79.45462689948937, -113.68787702296575), (53.67540678580275, 42.572831797156425), (-71.06183617597156, 78.81920296452), (30.027202311515296, -170.27974220850373), (-76.58779492175562, -87.45508007824424), (58.951095033377044, 20.865852369142544), (8.384792437574475, -104.54676182146576), (4.467957356307281, 65.62804025914681), (65.63677060337184, 120.81080965380022), (74.37843645891985, 68.1075585805518), (-89.97953993942666, -146.72583184055622), (1.1515274368632902, 147.77201836966407), (-28.46348175882069, 143.49281 ...

# %%
# Create a list for holding the cities.
cities=[]

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
# Print the city count to confirm sufficient count.
print(len(cities))
print(cities)
# Out:
# 734
# ['zyryanka', 'cape town', 'port alfred', 'grand river south east', 'nalut', 'ushuaia', 'vaini', 'mataura', 'taolanaro', 'lakatoro', 'clyde river', 'vila velha', 'port hardy', 'avera', 'beihai', 'santa marinella', 'matara', 'ponta delgada', 'bredasdorp', 'avarua', 'kaitangata', 'omboue', 'richards bay', 'bluff', 'opuwo', 'port elizabeth', 'veraval', 'dipkarpaz', 'busselton', 'hithadhoo', 'lakes entrance', 'yellowknife', 'magadan', 'jiaocheng', 'sorong', 'saurimo', 'kindu', 'palabuhanratu', 'henties bay', 'auki', 'narsaq', 'punta arenas', 'atuona', 'acapulco', 'buraydah', 'rikitea', 'cabo san lucas', 'toora-khem', 'salalah', 'lebu', 'provideniya', 'ahipara', 'olafsvik', 'sitka', 'porbandar', 'dicabisagan', 'kodiak', 'nishihara', 'klaksvik', 'sao filipe', 'new norfolk', 'castro', 'chiang rai', 'marsaxlokk', 'hermanus', 'tomakomai', 'nipawin', 'lithakia', 'zemetchino', 'kapaa', 'maarianhamina', 'mahibadhoo', 'vilyuysk', 'sovetskiy', 'lorengau', 'broken hill', 'mar del plata', 'whitecourt', 'barrow', 'abu dhabi', 'ribeira grande', 'qaanaaq', 'nanortalik', 'chuy', 'talnakh', 'ponta do sol', 'ierapetra', 'norman wells', 'bethel', 'ostrovnoy', 'tiksi', 'mutoko', 'nagapattinam', 'nikolskoye', 'lyuban', 'illoqqortoormiut', 'baykit', 'jamestown', 'mahebourg', 'colac', 'airai', 'albany', 'hobart', 'butaritari', 'sorvag', 'faya', 'bodden town', 'heihe', 'pishin', 'tasiilaq', 'chara', 'chichawatni', 'nizhneyansk', 'wuda', 'surt', 'bastia', 'ozgon', 'matay', 'caravelas', 'tabou', 'bilibino', 'chokurdakh', 'palmer', 'santa luzia', 'tulsa', 'lompoc', 'barentsburg', 'tromso', 'rasulnagar', 'altamira', 'east london', 'sola', 'husavik', 'saint george', 'pimentel', 'boende', 'hayden', 'morehead', 'kathmandu', 'ugoofaaru', 'moose factory', 'vilhena', 'vaitupu', 'hokitika', 'dingle', 'nador', 'amderma', 'barawe', 'novo oriente', 'mezhdurechensk', 'samusu', 'biltine', 'crotone', 'kaniama', 'ayagoz', 'thompson', 'lagoa', 'aswan', 'kiunga', 'panji', 'saint-philippe', 'rio grande', 'general roca', 'arraial do cabo', 'jujuy', 'erenhot', 'sabha', 'gejiu', 'khatanga', 'jaisalmer', 'yazd', 'cururupu', 'lagos', 'polazna', 'songjianghe', 'puerto ayora', 'kavieng', 'yingzhong', 'beatrice', 'komsomolskiy', 'erzin', 'cayenne', 'altay', 'lethem', 'iskateley', 'sobolevo', 'severo-kurilsk', 'torbay', 'korla', 'tumannyy', 'najran', 'basco', 'palu', 'cieza', 'sinnamary', 'hami', 'puerto escondido', 'ewa beach', 'ketchikan', 'kangaatsiaq', 'bilma', 'akyab', 'yar-sale', 'saldanha', 'tarbagatay', 'belushya guba', 'iqaluit', 'orgun', 'hofn', 'guarapari', 'ust-maya', 'chumikan', 'tuktoyaktuk', 'souillac', 'orlik', 'mount isa', 'kautokeino', 'esperance', 'libreville', 'alghero', 'turukhansk', 'la ronge', 'valdemarpils', 'cidreira', 'sisimiut', 'port hawkesbury', 'port hedland', 'holland', 'hervey bay', 'ginir', 'hasaki', 'bull savanna', 'davila', 'sorland', 'dayong', 'acarau', 'saskylakh', 'gorontalo', 'roma', 'zhizdra', 'sumbawa', 'la cruz', 'strezhevoy', 'wenling', 'maykain', 'hurghada', 'bergen', 'tuatapere', 'poum', 'dikson', 'aras', 'saint anthony', 'voh', 'novyy urgal', 'karaul', 'mantua', 'karratha', 'hilo', 'koslan', 'colesberg', 'mount gambier', 'makakilo city', 'inzer', 'diamantino', 'flagstaff', 'portland', 'gobabis', 'saleaula', 'pitimbu', 'mweka', 'alofi', 'ilo', 'bambous virieux', 'tidore', 'san luis', 'longyearbyen', 'kloulklubed', 'bonavista', 'bandarbeyla', 'chicama', 'guerrero negro', 'biak', 'carutapera', 'vila franca do campo', 'khandbari', 'buctzotz', 'nuuk', 'eenhana', 'camocim', 'we', 'saumur', 'necochea', 'bacungan', 'gryazi', 'belyy yar', 'baboua', 'segovia', 'kamenka', 'san cristobal', 'lavrentiya', 'jalu', 'victoria', 'loxstedt', 'bure', 'shakiso', 'pierre', 'te anau', 'xuddur', 'den helder', 'tucurui', 'meulaboh', 'georgetown', 'anar darreh', 'youkounkoun', 'panama city', 'maralal', 'mikhaylovka', 'nago', 'carnarvon', 'play cu', 'bubaque', 'faanui', 'port blair', 'zalantun', 'chebenki', 'ondangwa', 'ucluelet', 'thurso', 'rodino', 'pevek', 'neryu ...

# %%
# Create an empty list to hold the weather data.
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count=1
set_count=1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if(i%50==0 and i>=50):
        set_count+=1
        record_count=1
        
    # Create endpoint URL with each city.
    city_url=url+"&q="+city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing record {record_count} of Set {set_count}| {city}")
        
    # Add 1 to the record count.
    record_count+=1
    try:
        # Parse the JSON and retrieve data.
        city_weather=requests.get(city_url).json()
        # Parse out the needed data.
        city_country=city_weather['sys']['country']
        city_lat=city_weather['coord']['lat']
        city_lng=city_weather['coord']['lon']
        city_max_temp=city_weather['main']['temp_max']
        city_humidity=city_weather['main']['humidity']
        city_clouds=city_weather['clouds']['all']
        city_wind=city_weather['wind']['speed']
        city_curr_description=city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        #city_date=datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({'City':city.title(),
                          'Country':city_country,
                          'Lat':city_lat,
                          'Lng':city_lng,
                          'Max Temp':city_max_temp,
                          'Humidity':city_humidity,
                          'Cloudiness':city_clouds,
                          'Wind Speed':city_wind,
                          'Current Description':city_curr_description
                           })
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print('-----------------------')
print('Data Retrieval Complete')
print('-----------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing record 1 of Set 1| zyryanka
# Processing record 2 of Set 1| cape town
# Processing record 3 of Set 1| port alfred
# Processing record 4 of Set 1| grand river south east
# City not found. Skipping...
# Processing record 5 of Set 1| nalut
# Processing record 6 of Set 1| ushuaia
# Processing record 7 of Set 1| vaini
# Processing record 8 of Set 1| mataura
# Processing record 9 of Set 1| taolanaro
# City not found. Skipping...
# Processing record 10 of Set 1| lakatoro
# Processing record 11 of Set 1| clyde river
# Processing record 12 of Set 1| vila velha
# Processing record 13 of Set 1| port hardy
# Processing record 14 of Set 1| avera
# Processing record 15 of Set 1| beihai
# Processing record 16 of Set 1| santa marinella
# Processing record 17 of Set 1| matara
# Processing record 18 of Set 1| ponta delgada
# Processing record 19 of Set 1| bredasdorp
# Processing record 20 of Set 1| avarua
# Processing record 21 of Set 1| kaitangata
# Processing record 22 of Set 1| omboue
# Processing record 23 of Set 1| richards bay
# Processing record 24 of Set 1| bluff
# Processing record 25 of Set 1| opuwo
# Processing record 26 of Set 1| port elizabeth
# Processing record 27 of Set 1| veraval
# Processing record 28 of Set 1| dipkarpaz
# City not found. Skipping...
# Processing record 29 of Set 1| busselton
# Processing record 30 of Set 1| hithadhoo
# Processing record 31 of Set 1| lakes entrance
# Processing record 32 of Set 1| yellowknife
# Processing record 33 of Set 1| magadan
# Processing record 34 of Set 1| jiaocheng
# Processing record 35 of Set 1| sorong
# Processing record 36 of Set 1| saurimo
# Processing record 37 of Set 1| kindu
# Processing record 38 of Set 1| palabuhanratu
# City not found. Skipping...
# Processing record 39 of Set 1| henties bay
# Processing record 40 of Set 1| auki
# Processing record 41 of Set 1| narsaq
# Processing record 42 of Set 1| punta arenas
# Processing record 43 of Set 1| atuona
# Processing record 44 of Set 1| acapulco
# Processing record 45 of Set 1| buraydah
# Processing record 46 of Set 1| rikitea
# Processing record 47 of Set 1| cabo san lucas
# Processing record 48 of Set 1| toora-khem
# Processing record 49 of Set 1| salalah
# Processing record 50 of Set 1| lebu
# Processing record 1 of Set 2| provideniya
# Processing record 2 of Set 2| ahipara
# Processing record 3 of Set 2| olafsvik
# Processing record 4 of Set 2| sitka
# Processing record 5 of Set 2| porbandar
# Processing record 6 of Set 2| dicabisagan
# Processing record 7 of Set 2| kodiak
# Processing record 8 of Set 2| nishihara
# Processing record 9 of Set 2| klaksvik
# Processing record 10 of Set 2| sao filipe
# Processing record 11 of Set 2| new norfolk
# Processing record 12 of Set 2| castro
# Processing record 13 of Set 2| chiang rai
# Processing record 14 of Set 2| marsaxlokk
# Processing record 15 of Set 2| hermanus
# Processing record 16 of Set 2| tomakomai
# Processing record 17 of Set 2| nipawin
# Processing record 18 of Set 2| lithakia
# Processing record 19 of Set 2| zemetchino
# Processing record 20 of Set 2| kapaa
# Processing record 21 of Set 2| maarianhamina
# Processing record 22 of Set 2| mahibadhoo
# Processing record 23 of Set 2| vilyuysk
# Processing record 24 of Set 2| sovetskiy
# Processing record 25 of Set 2| lorengau
# Processing record 26 of Set 2| broken hill
# Processing record 27 of Set 2| mar del plata
# Processing record 28 of Set 2| whitecourt
# Processing record 29 of Set 2| barrow
# Processing record 30 of Set 2| abu dhabi
# Processing record 31 of Set 2| ribeira grande
# Processing record 32 of Set 2| qaanaaq
# Processing record 33 of Set 2| nanortalik
# Processing record 34 of Set 2| chuy
# Processing record 35 of Set 2| talnakh
# Processing record 36 of Set 2| ponta do sol
# Processing record 37 of Set 2| ierapetra
# Processing record 38 of Set 2| norman wells
# Processing record 39 of Set 2| bethel
# Processing record 40 of Set 2| ostrovnoy
# Processing record 41 of Set 2| tiksi
# Processing record 42 of Set 2| mutoko
# Processing record 43 of Set 2| nagapattinam
# Processing record 44 of Set 2| nikolskoye
# Processing record 45 of Set 2| lyuban
# Processing record 46 of Set 2| illoqqortoormiut
# City not found. Skipping...
# Processing record 47 of Set 2| baykit
# Processing record 48 of Set 2| jamestown
# Processing record 49 of Set 2| mahebourg
# Processing record 50 of Set 2| colac
# Processing record 1 of Set 3| airai
# Processing record 2 of Set 3| albany
# Processing record 3 of Set 3| hobart
# Processing record 4 of Set 3| butaritari
# Processing record 5 of Set 3| sorvag
# City not found. Skipping...
# Processing record 6 of Set 3| faya
# Processing record 7 of Set 3| bodden town
# Processing record 8 of Set 3| heihe
# Processing record 9 of Set 3| pishin
# Processing record 10 of Set 3| tasiilaq
# Processing record 11 of Set 3| chara
# Processing record 12 of Set 3| chichawatni
# Processing record 13 of Set 3| nizhneyansk
# City not found. Skipping...
# Processing record 14 of Set 3| wuda
# Processing record 15 of Set 3| surt
# Processing record 16 of Set 3| bastia
# Processing record 17 of Set 3| ozgon
# City not found. Skipping...
# Processing record 18 of Set 3| matay
# Processing record 19 of Set 3| caravelas
# Processing record 20 of Set 3| tabou
# Processing record 21 of Set 3| bilibino
# Processing record 22 of Set 3| chokurdakh
# Processing record 23 of Set 3| palmer
# Processing record 24 of Set 3| santa luzia
# Processing record 25 of Set 3| tulsa
# Processing record 26 of Set 3| lompoc
# Processing record 27 of Set 3| barentsburg
# City not found. Skipping...
# Processing record 28 of Set 3| tromso
# Processing record 29 of Set 3| rasulnagar
# Processing record 30 of Set 3| altamira
# Processing record 31 of Set 3| east london
# Processing record 32 of Set 3| sola
# Processing record 33 of Set 3| husavik
# Processing record 34 of Set 3| saint george
# Processing record 35 of Set 3| pimentel
# Processing record 36 of Set 3| boende
# Processing record 37 of Set 3| hayden
# Processing record 38 of Set 3| morehead
# Processing record 39 of Set 3| kathmandu
# Processing record 40 of Set 3| ugoofaaru
# Processing record 41 of Set 3| moose factory
# Processing record 42 of Set 3| vilhena
# Processing record 43 of Set 3| vaitupu
# City not found. Skipping...
# Processing record 44 of Set 3| hokitika
# Processing record 45 of Set 3| dingle
# Processing record 46 of Set 3| nador
# Processing record 47 of Set 3| amderma
# City not found. Skipping...
# Processing record 48 of Set 3| barawe
# City not found. Skipping...
# Processing record 49 of Set 3| novo oriente
# Processing record 50 of Set 3| mezhdurechensk
# Processing record 1 of Set 4| samusu
# City not found. Skipping...
# Processing record 2 of Set 4| biltine
# Processing record 3 of Set 4| crotone
# Processing record 4 of Set 4| kaniama
# Processing record 5 of Set 4| ayagoz
# Processing record 6 of Set 4| thompson
# Processing record 7 of Set 4| lagoa
# Processing record 8 of Set 4| aswan
# Processing record 9 of Set 4| kiunga
# Processing record 10 of Set 4| panji
# Processing record 11 of Set 4| saint-philippe
# Processing record 12 of Set 4| rio grande
# Processing record 13 of Set 4| general roca
# Processing record 14 of Set 4| arraial do cabo
# Processing record 15 of Set 4| jujuy
# City not found. Skipping...
# Processing record 16 of Set 4| erenhot
# Processing record 17 of Set 4| sabha
# Processing record 18 of Set 4| gejiu
# Processing record 19 of Set 4| khatanga
# Processing record 20 of Set 4| jaisalmer
# Processing record 21 of Set 4| yazd
# Processing record 22 of Set 4| cururupu
# Processing record 23 of Set 4| lagos
# Processing record 24 of Set 4| polazna
# Processing record 25 of Set 4| songjianghe
# Processing record 26 of Set 4| puerto ayora
# Processing record 27 of Set 4| kavieng
# Processing record 28 of Set 4| yingzhong
# City not found. Skipping...
# Processing record 29 of Set 4| beatrice
# Processing record 30 of Set 4| komsomolskiy
# Processing record 31 of Set 4| erzin
# Processing record 32 of Set 4| cayenne
# Processing record 33 of Set 4| altay
# Processing record 34 of Set 4| lethem
# Processing record 35 of Set 4| iskateley
# Processing record 36 of Set 4| sobolevo
# Processing record 37 of Set 4| severo-kurilsk
# Processing record 38 of Set 4| torbay
# Processing record 39 of Set 4| korla
# Processing record 40 of Set 4| tumannyy
# City not found. Skipping...
# Processing record 41 of Set 4| najran
# Processing record 42 of Set 4| basco
# Processing record 43 of Set 4| palu
# Processing record 44 of Set 4| cieza
# Processing record 45 of Set 4| sinnamary
# Processing record 46 of Set 4| hami
# Processing record 47 of Set 4| puerto escondido
# Processing record 48 of Set 4| ewa beach
# Processing record 49 of Set 4| ketchikan
# Processing record 50 of Set 4| kangaatsiaq
# Processing record 1 of Set 5| bilma
# Processing record 2 of Set 5| akyab
# Processing record 3 of Set 5| yar-sale
# Processing record 4 of Set 5| saldanha
# Processing record 5 of Set 5| tarbagatay
# Processing record 6 of Set 5| belushya guba
# City not found. Skipping...
# Processing record 7 of Set 5| iqaluit
# Processing record 8 of Set 5| orgun
# City not found. Skipping...
# Processing record 9 of Set 5| hofn
# Processing record 10 of Set 5| guarapari
# Processing record 11 of Set 5| ust-maya
# Processing record 12 of Set 5| chumikan
# Processing record 13 of Set 5| tuktoyaktuk
# Processing record 14 of Set 5| souillac
# Processing record 15 of Set 5| orlik
# Processing record 16 of Set 5| mount isa
# Processing record 17 of Set 5| kautokeino
# Processing record 18 of Set 5| esperance
# Processing record 19 of Set 5| libreville
# Processing record 20 of Set 5| alghero
# Processing record 21 of Set 5| turukhansk
# Processing record 22 of Set 5| la ronge
# Processing record 23 of Set 5| valdemarpils
# Processing record 24 of Set 5| cidreira
# Processing record 25 of Set 5| sisimiut
# Processing record 26 of Set 5| port hawkesbury
# Processing record 27 of Set 5| port hedland
# Processing record 28 of Set 5| holland
# Processing record 29 of Set 5| hervey bay
# Processing record 30 of Set 5| ginir
# Processing record 31 of Set 5| hasaki
# Processing record 32 of Set 5| bull savanna
# Processing record 33 of Set 5| davila
# Processing record 34 of Set 5| sorland
# Processing record 35 of Set 5| dayong
# Processing record 36 of Set 5| acarau
# Processing record 37 of Set 5| saskylakh
# Processing record 38 of Set 5| gorontalo
# Processing record 39 of Set 5| roma
# Processing record 40 of Set 5| zhizdra
# Processing record 41 of Set 5| sumbawa
# City not found. Skipping...
# Processing record 42 of Set 5| la cruz
# Processing record 43 of Set 5| strezhevoy
# Processing record 44 of Set 5| wenling
# Processing record 45 of Set 5| maykain
# City not found. Skipping...
# Processing record 46 of Set 5| hurghada
# Processing record 47 of Set 5| bergen
# Processing record 48 of Set 5| tuatapere
# Processing record 49 of Set 5| poum
# Processing record 50 of Set 5| dikson
# Processing record 1 of Set 6| aras
# Processing record 2 of Set 6| saint anthony
# Processing record 3 of Set 6| voh
# Processing record 4 of Set 6| novyy urgal
# Processing record 5 of Set 6| karaul
# City not found. Skipping...
# Processing record 6 of Set 6| mantua
# Processing record 7 of Set 6| karratha
# Processing record 8 of Set 6| hilo
# Processing record 9 of Set 6| koslan
# Processing record 10 of Set 6| colesberg
# Processing record 11 of Set 6| mount gambier
# Processing record 12 of Set 6| makakilo city
# Processing record 13 of Set 6| inzer
# Processing record 14 of Set 6| diamantino
# Processing record 15 of Set 6| flagstaff
# Processing record 16 of Set 6| portland
# Processing record 17 of Set 6| gobabis
# Processing record 18 of Set 6| saleaula
# City not found. Skipping...
# Processing record 19 of Set 6| pitimbu
# Processing record 20 of Set 6| mweka
# Processing record 21 of Set 6| alofi
# Processing record 22 of Set 6| ilo
# Processing record 23 of Set 6| bambous virieux
# Processing record 24 of Set 6| tidore
# City not found. Skipping...
# Processing record 25 of Set 6| san luis
# Processing record 26 of Set 6| longyearbyen
# Processing record 27 of Set 6| kloulklubed
# Processing record 28 of Set 6| bonavista
# Processing record 29 of Set 6| bandarbeyla
# Processing record 30 of Set 6| chicama
# Processing record 31 of Set 6| guerrero negro
# Processing record 32 of Set 6| biak
# Processing record 33 of Set 6| carutapera
# Processing record 34 of Set 6| vila franca do campo
# Processing record 35 of Set 6| khandbari
# Processing record 36 of Set 6| buctzotz
# Processing record 37 of Set 6| nuuk
# Processing record 38 of Set 6| eenhana
# Processing record 39 of Set 6| camocim
# Processing record 40 of Set 6| we
# City not found. Skipping...
# Processing record 41 of Set 6| saumur
# Processing record 42 of Set 6| necochea
# Processing record 43 of Set 6| bacungan
# Processing record 44 of Set 6| gryazi
# Processing record 45 of Set 6| belyy yar
# Processing record 46 of Set 6| baboua
# City not found. Skipping...
# Processing record 47 of Set 6| segovia
# Processing record 48 of Set 6| kamenka
# Processing record 49 of Set 6| san cristobal
# Processing record 50 of Set 6| lavrentiya
# Processing record 1 of Set 7| jalu
# Processing record 2 of Set 7| victoria
# Processing record 3 of Set 7| loxstedt
# Processing record 4 of Set 7| bure
# Processing record 5 of Set 7| shakiso
# Processing record 6 of Set 7| pierre
# Processing record 7 of Set 7| te anau
# Processing record 8 of Set 7| xuddur
# Processing record 9 of Set 7| den helder
# Processing record 10 of Set 7| tucurui
# Processing record 11 of Set 7| meulaboh
# Processing record 12 of Set 7| georgetown
# Processing record 13 of Set 7| anar darreh
# City not found. Skipping...
# Processing record 14 of Set 7| youkounkoun
# Processing record 15 of Set 7| panama city
# Processing record 16 of Set 7| maralal
# Processing record 17 of Set 7| mikhaylovka
# Processing record 18 of Set 7| nago
# Processing record 19 of Set 7| carnarvon
# Processing record 20 of Set 7| play cu
# City not found. Skipping...
# Processing record 21 of Set 7| bubaque
# Processing record 22 of Set 7| faanui
# Processing record 23 of Set 7| port blair
# Processing record 24 of Set 7| zalantun
# Processing record 25 of Set 7| chebenki
# Processing record 26 of Set 7| ondangwa
# Processing record 27 of Set 7| ucluelet
# Processing record 28 of Set 7| thurso
# Processing record 29 of Set 7| rodino
# Processing record 30 of Set 7| pevek
# Processing record 31 of Set 7| neryungri
# Processing record 32 of Set 7| upernavik
# Processing record 33 of Set 7| tateyama
# Processing record 34 of Set 7| cockburn town
# Processing record 35 of Set 7| kintampo
# Processing record 36 of Set 7| tocopilla
# Processing record 37 of Set 7| san juan
# Processing record 38 of Set 7| tsihombe
# City not found. Skipping...
# Processing record 39 of Set 7| cap-haitien
# Processing record 40 of Set 7| fujin
# Processing record 41 of Set 7| fitchburg
# Processing record 42 of Set 7| malwan
# City not found. Skipping...
# Processing record 43 of Set 7| carman
# Processing record 44 of Set 7| kruisfontein
# Processing record 45 of Set 7| yulara
# Processing record 46 of Set 7| sumkino
# Processing record 47 of Set 7| coro
# Processing record 48 of Set 7| kushmurun
# Processing record 49 of Set 7| kupang
# Processing record 50 of Set 7| denpasar
# Processing record 1 of Set 8| sabla
# Processing record 2 of Set 8| alice springs
# Processing record 3 of Set 8| maningrida
# Processing record 4 of Set 8| saint-augustin
# Processing record 5 of Set 8| neiafu
# Processing record 6 of Set 8| viedma
# Processing record 7 of Set 8| petropavlovsk-kamchatskiy
# Processing record 8 of Set 8| sri aman
# Processing record 9 of Set 8| quatre cocos
# Processing record 10 of Set 8| shingu
# Processing record 11 of Set 8| marcona
# City not found. Skipping...
# Processing record 12 of Set 8| dobric
# Processing record 13 of Set 8| saryshagan
# City not found. Skipping...
# Processing record 14 of Set 8| bengkulu
# Processing record 15 of Set 8| port lincoln
# Processing record 16 of Set 8| kropotkin
# Processing record 17 of Set 8| sanandaj
# Processing record 18 of Set 8| santa rosa
# Processing record 19 of Set 8| port-gentil
# Processing record 20 of Set 8| biga
# Processing record 21 of Set 8| tura
# Processing record 22 of Set 8| mullaitivu
# City not found. Skipping...
# Processing record 23 of Set 8| vardo
# Processing record 24 of Set 8| college
# Processing record 25 of Set 8| xichang
# Processing record 26 of Set 8| hammerfest
# Processing record 27 of Set 8| thanh hoa
# Processing record 28 of Set 8| egvekinot
# Processing record 29 of Set 8| pisco
# Processing record 30 of Set 8| calama
# Processing record 31 of Set 8| half moon bay
# Processing record 32 of Set 8| dyatkovo
# Processing record 33 of Set 8| solwezi
# Processing record 34 of Set 8| fairbanks
# Processing record 35 of Set 8| wazzan
# City not found. Skipping...
# Processing record 36 of Set 8| fort saint james
# Processing record 37 of Set 8| abnub
# Processing record 38 of Set 8| yaring
# Processing record 39 of Set 8| urucui
# Processing record 40 of Set 8| san andres
# Processing record 41 of Set 8| birin
# Processing record 42 of Set 8| inuvik
# Processing record 43 of Set 8| vanimo
# Processing record 44 of Set 8| dalby
# Processing record 45 of Set 8| zhanaozen
# Processing record 46 of Set 8| mys shmidta
# City not found. Skipping...
# Processing record 47 of Set 8| shillong
# Processing record 48 of Set 8| oudtshoorn
# Processing record 49 of Set 8| nguiu
# City not found. Skipping...
# Processing record 50 of Set 8| chermoz
# Processing record 1 of Set 9| cabedelo
# Processing record 2 of Set 9| ipixuna
# Processing record 3 of Set 9| nawabganj
# Processing record 4 of Set 9| klyuchi
# Processing record 5 of Set 9| sokoni
# Processing record 6 of Set 9| kudahuvadhoo
# Processing record 7 of Set 9| raga
# Processing record 8 of Set 9| leningradskiy
# Processing record 9 of Set 9| ilulissat
# Processing record 10 of Set 9| storsteinnes
# Processing record 11 of Set 9| ordu
# Processing record 12 of Set 9| merzifon
# Processing record 13 of Set 9| luanda
# Processing record 14 of Set 9| novovarshavka
# Processing record 15 of Set 9| panzhihua
# Processing record 16 of Set 9| ayaviri
# Processing record 17 of Set 9| madingou
# Processing record 18 of Set 9| ballina
# Processing record 19 of Set 9| kalmunai
# Processing record 20 of Set 9| kahului
# Processing record 21 of Set 9| nyurba
# Processing record 22 of Set 9| camana
# Processing record 23 of Set 9| saint-louis
# Processing record 24 of Set 9| ca mau
# Processing record 25 of Set 9| mayor pablo lagerenza
# Processing record 26 of Set 9| chaman
# Processing record 27 of Set 9| deputatskiy
# Processing record 28 of Set 9| warren
# Processing record 29 of Set 9| maniitsoq
# Processing record 30 of Set 9| daru
# Processing record 31 of Set 9| nokaneng
# Processing record 32 of Set 9| luoyang
# Processing record 33 of Set 9| teguldet
# Processing record 34 of Set 9| les cayes
# Processing record 35 of Set 9| mosquera
# Processing record 36 of Set 9| winslow
# Processing record 37 of Set 9| mayo
# Processing record 38 of Set 9| axim
# Processing record 39 of Set 9| araceli
# Processing record 40 of Set 9| myhove
# Processing record 41 of Set 9| attawapiskat
# City not found. Skipping...
# Processing record 42 of Set 9| guthrie
# Processing record 43 of Set 9| chupa
# Processing record 44 of Set 9| prescott
# Processing record 45 of Set 9| araouane
# Processing record 46 of Set 9| fortuna
# Processing record 47 of Set 9| fare
# Processing record 48 of Set 9| woodstock
# Processing record 49 of Set 9| wainwright
# Processing record 50 of Set 9| khandyga
# Processing record 1 of Set 10| obregon
# Processing record 2 of Set 10| anadyr
# Processing record 3 of Set 10| sambava
# Processing record 4 of Set 10| coquimbo
# Processing record 5 of Set 10| carballo
# Processing record 6 of Set 10| mabaruma
# Processing record 7 of Set 10| natal
# Processing record 8 of Set 10| malanje
# Processing record 9 of Set 10| grenfell
# Processing record 10 of Set 10| steinbach
# Processing record 11 of Set 10| macusani
# Processing record 12 of Set 10| hay river
# Processing record 13 of Set 10| san jose
# Processing record 14 of Set 10| piacabucu
# Processing record 15 of Set 10| batagay-alyta
# Processing record 16 of Set 10| grand centre
# City not found. Skipping...
# Processing record 17 of Set 10| satitoa
# City not found. Skipping...
# Processing record 18 of Set 10| kuantan
# Processing record 19 of Set 10| eureka
# Processing record 20 of Set 10| borogontsy
# Processing record 21 of Set 10| alta floresta
# Processing record 22 of Set 10| karabuk
# Processing record 23 of Set 10| akdepe
# Processing record 24 of Set 10| ayan
# Processing record 25 of Set 10| fort saint john
# City not found. Skipping...
# Processing record 26 of Set 10| grindavik
# Processing record 27 of Set 10| mocuba
# Processing record 28 of Set 10| anloga
# Processing record 29 of Set 10| katsuura
# Processing record 30 of Set 10| chabua
# Processing record 31 of Set 10| san patricio
# Processing record 32 of Set 10| pangnirtung
# Processing record 33 of Set 10| kamenskoye
# City not found. Skipping...
# Processing record 34 of Set 10| labytnangi
# Processing record 35 of Set 10| ancud
# Processing record 36 of Set 10| salmas
# Processing record 37 of Set 10| springdale
# Processing record 38 of Set 10| vanavara
# Processing record 39 of Set 10| la palma
# Processing record 40 of Set 10| maceio
# Processing record 41 of Set 10| san jeronimo
# Processing record 42 of Set 10| scalloway
# City not found. Skipping...
# Processing record 43 of Set 10| cehegin
# Processing record 44 of Set 10| nouadhibou
# Processing record 45 of Set 10| okhotsk
# Processing record 46 of Set 10| scottsburgh
# City not found. Skipping...
# Processing record 47 of Set 10| connersville
# Processing record 48 of Set 10| namibe
# Processing record 49 of Set 10| banda aceh
# Processing record 50 of Set 10| khani
# Processing record 1 of Set 11| salinas
# Processing record 2 of Set 11| mrirt
# City not found. Skipping...
# Processing record 3 of Set 11| basoko
# Processing record 4 of Set 11| nemuro
# Processing record 5 of Set 11| alekseyevsk
# Processing record 6 of Set 11| lamu
# Processing record 7 of Set 11| sawakin
# Processing record 8 of Set 11| oranjestad
# Processing record 9 of Set 11| kumluca
# Processing record 10 of Set 11| malatya
# Processing record 11 of Set 11| mana
# Processing record 12 of Set 11| sentyabrskiy
# City not found. Skipping...
# Processing record 13 of Set 11| batemans bay
# Processing record 14 of Set 11| kaminskiy
# Processing record 15 of Set 11| dawlatabad
# Processing record 16 of Set 11| esna
# Processing record 17 of Set 11| beyneu
# Processing record 18 of Set 11| pacific grove
# Processing record 19 of Set 11| belaya gora
# Processing record 20 of Set 11| pervoye maya
# Processing record 21 of Set 11| rochegda
# Processing record 22 of Set 11| biryukove
# Processing record 23 of Set 11| codrington
# Processing record 24 of Set 11| lloydminster
# Processing record 25 of Set 11| luderitz
# Processing record 26 of Set 11| doctor pedro p. pena
# City not found. Skipping...
# Processing record 27 of Set 11| tarnogskiy gorodok
# Processing record 28 of Set 11| atar
# Processing record 29 of Set 11| umm kaddadah
# Processing record 30 of Set 11| samur
# Processing record 31 of Set 11| gari
# Processing record 32 of Set 11| sioux lookout
# Processing record 33 of Set 11| samalaeulu
# City not found. Skipping...
# Processing record 34 of Set 11| pemangkat
# Processing record 35 of Set 11| cherskiy
# Processing record 36 of Set 11| murud
# Processing record 37 of Set 11| tucuman
# Processing record 38 of Set 11| vega de alatorre
# Processing record 39 of Set 11| bokspits
# City not found. Skipping...
# Processing record 40 of Set 11| nanakuli
# Processing record 41 of Set 11| hambantota
# Processing record 42 of Set 11| aguimes
# Processing record 43 of Set 11| otane
# Processing record 44 of Set 11| namatanai
# Processing record 45 of Set 11| coihaique
# Processing record 46 of Set 11| isangel
# Processing record 47 of Set 11| mareeba
# Processing record 48 of Set 11| burgeo
# Processing record 49 of Set 11| zabaykalsk
# Processing record 50 of Set 11| uusikaupunki
# Processing record 1 of Set 12| maxixe
# Processing record 2 of Set 12| shakawe
# Processing record 3 of Set 12| solnechnyy
# Processing record 4 of Set 12| libenge
# Processing record 5 of Set 12| constitucion
# Processing record 6 of Set 12| ruidoso
# Processing record 7 of Set 12| san policarpo
# Processing record 8 of Set 12| lokachi
# Processing record 9 of Set 12| toamasina
# Processing record 10 of Set 12| plettenberg bay
# Processing record 11 of Set 12| katangli
# Processing record 12 of Set 12| ovalle
# Processing record 13 of Set 12| tukrah
# Processing record 14 of Set 12| tabialan
# City not found. Skipping...
# Processing record 15 of Set 12| sangin
# Processing record 16 of Set 12| jocon
# Processing record 17 of Set 12| marawi
# Processing record 18 of Set 12| kutum
# Processing record 19 of Set 12| milyutinskaya
# Processing record 20 of Set 12| saint-felix-de-valois
# Processing record 21 of Set 12| shasta lake
# Processing record 22 of Set 12| aklavik
# Processing record 23 of Set 12| loma bonita
# Processing record 24 of Set 12| saint-leu
# Processing record 25 of Set 12| ballstad
# City not found. Skipping...
# Processing record 26 of Set 12| paamiut
# Processing record 27 of Set 12| havre-saint-pierre
# Processing record 28 of Set 12| marabba
# Processing record 29 of Set 12| raahe
# Processing record 30 of Set 12| lukovetskiy
# Processing record 31 of Set 12| tonaya
# Processing record 32 of Set 12| mapiri
# Processing record 33 of Set 12| narathiwat
# Processing record 34 of Set 12| marinette
# Processing record 35 of Set 12| flinders
# Processing record 36 of Set 12| soyo
# Processing record 37 of Set 12| lake cowichan
# Processing record 38 of Set 12| thunder bay
# Processing record 39 of Set 12| sur
# Processing record 40 of Set 12| kincardine
# Processing record 41 of Set 12| hualmay
# Processing record 42 of Set 12| lalmohan
# Processing record 43 of Set 12| jutai
# Processing record 44 of Set 12| marathon
# Processing record 45 of Set 12| warqla
# City not found. Skipping...
# Processing record 46 of Set 12| yaan
# Processing record 47 of Set 12| key west
# Processing record 48 of Set 12| aviles
# Processing record 49 of Set 12| tsaratanana
# Processing record 50 of Set 12| urumqi
# Processing record 1 of Set 13| xai-xai
# Processing record 2 of Set 13| tubruq
# City not found. Skipping...
# Processing record 3 of Set 13| mitsamiouli
# Processing record 4 of Set 13| laksham
# Processing record 5 of Set 13| mehamn
# Processing record 6 of Set 13| nefteyugansk
# Processing record 7 of Set 13| marsa matruh
# Processing record 8 of Set 13| nortelandia
# Processing record 9 of Set 13| kokopo
# Processing record 10 of Set 13| seoul
# Processing record 11 of Set 13| shilong
# Processing record 12 of Set 13| iquitos
# Processing record 13 of Set 13| waingapu
# Processing record 14 of Set 13| los llanos de aridane
# Processing record 15 of Set 13| touros
# Processing record 16 of Set 13| fort nelson
# Processing record 17 of Set 13| ambon
# Processing record 18 of Set 13| christchurch
# Processing record 19 of Set 13| chagda
# City not found. Skipping...
# Processing record 20 of Set 13| trincomalee
# Processing record 21 of Set 13| kathu
# Processing record 22 of Set 13| nome
# Processing record 23 of Set 13| san pedro
# Processing record 24 of Set 13| grand forks
# Processing record 25 of Set 13| kiama
# Processing record 26 of Set 13| kazalinsk
# City not found. Skipping...
# Processing record 27 of Set 13| pachino
# Processing record 28 of Set 13| mbuji-mayi
# Processing record 29 of Set 13| babanusah
# City not found. Skipping...
# Processing record 30 of Set 13| sena madureira
# Processing record 31 of Set 13| zhanakorgan
# Processing record 32 of Set 13| tres arroyos
# Processing record 33 of Set 13| mecca
# Processing record 34 of Set 13| karwar
# Processing record 35 of Set 13| russell
# Processing record 36 of Set 13| hihifo
# City not found. Skipping...
# Processing record 37 of Set 13| tsumeb
# Processing record 38 of Set 13| alegrete
# Processing record 39 of Set 13| gizo
# Processing record 40 of Set 13| jacareacanga
# Processing record 41 of Set 13| agirish
# Processing record 42 of Set 13| kuytun
# Processing record 43 of Set 13| bud
# Processing record 44 of Set 13| lumeje
# Processing record 45 of Set 13| bacuit
# City not found. Skipping...
# Processing record 46 of Set 13| de-kastri
# Processing record 47 of Set 13| ulladulla
# Processing record 48 of Set 13| qaqortoq
# Processing record 49 of Set 13| homer
# Processing record 50 of Set 13| meiganga
# Processing record 1 of Set 14| harper
# Processing record 2 of Set 14| mwene-ditu
# Processing record 3 of Set 14| andevoranto
# City not found. Skipping...
# Processing record 4 of Set 14| khilok
# Processing record 5 of Set 14| falealupo
# City not found. Skipping...
# Processing record 6 of Set 14| putnam
# Processing record 7 of Set 14| langham
# Processing record 8 of Set 14| kaffrine
# Processing record 9 of Set 14| mersing
# Processing record 10 of Set 14| margate
# Processing record 11 of Set 14| saint-hyacinthe
# Processing record 12 of Set 14| edd
# Processing record 13 of Set 14| noumea
# Processing record 14 of Set 14| north myrtle beach
# Processing record 15 of Set 14| phalaborwa
# Processing record 16 of Set 14| lovington
# Processing record 17 of Set 14| lerwick
# Processing record 18 of Set 14| kresttsy
# Processing record 19 of Set 14| amapa
# Processing record 20 of Set 14| puerto leguizamo
# Processing record 21 of Set 14| vestmanna
# Processing record 22 of Set 14| cotoca
# Processing record 23 of Set 14| bathsheba
# Processing record 24 of Set 14| goderich
# Processing record 25 of Set 14| albania
# Processing record 26 of Set 14| buchanan
# Processing record 27 of Set 14| havelock
# Processing record 28 of Set 14| honiara
# Processing record 29 of Set 14| albion
# Processing record 30 of Set 14| jiuquan
# Processing record 31 of Set 14| bunol
# Processing record 32 of Set 14| rocha
# Processing record 33 of Set 14| chokwe
# Processing record 34 of Set 14| crawfordsville
# Processing record 35 of Set 14| matongo
# Processing record 36 of Set 14| falam
# Processing record 37 of Set 14| kisangani
# Processing record 38 of Set 14| katsiveli
# City not found. Skipping...
# Processing record 39 of Set 14| kedrovyy
# Processing record 40 of Set 14| sitio novo do tocantins
# Processing record 41 of Set 14| vaasa
# Processing record 42 of Set 14| balaghat
# Processing record 43 of Set 14| kota kinabalu
# Processing record 44 of Set 14| bosaso
# Processing record 45 of Set 14| ekhabi
# Processing record 46 of Set 14| graham
# Processing record 47 of Set 14| santa barbara
# Processing record 48 of Set 14| kyshtovka
# Processing record 49 of Set 14| kashi
# Processing record 50 of Set 14| diffa
# Processing record 1 of Set 15| makhinjauri
# Processing record 2 of Set 15| marolambo
# Processing record 3 of Set 15| saint-denis
# Processing record 4 of Set 15| hamilton
# Processing record 5 of Set 15| arman
# Processing record 6 of Set 15| west bay
# Processing record 7 of Set 15| hobyo
# Processing record 8 of Set 15| mackay
# Processing record 9 of Set 15| srednekolymsk
# Processing record 10 of Set 15| kastamonu
# Processing record 11 of Set 15| yanam
# Processing record 12 of Set 15| tazovskiy
# Processing record 13 of Set 15| dingzhou
# Processing record 14 of Set 15| beloha
# Processing record 15 of Set 15| chitipa
# Processing record 16 of Set 15| kununurra
# Processing record 17 of Set 15| ardistan
# City not found. Skipping...
# Processing record 18 of Set 15| san carlos de bariloche
# Processing record 19 of Set 15| kundiawa
# Processing record 20 of Set 15| solano
# Processing record 21 of Set 15| mergui
# City not found. Skipping...
# Processing record 22 of Set 15| wewak
# Processing record 23 of Set 15| sturgeon falls
# Processing record 24 of Set 15| frontera
# Processing record 25 of Set 15| siloam springs
# Processing record 26 of Set 15| zheleznodorozhnyy
# Processing record 27 of Set 15| houma
# Processing record 28 of Set 15| plaster rock
# Processing record 29 of Set 15| petatlan
# Processing record 30 of Set 15| umzimvubu
# City not found. Skipping...
# Processing record 31 of Set 15| mahina
# Processing record 32 of Set 15| lancaster
# Processing record 33 of Set 15| bardiyah
# Processing record 34 of Set 15| lengshuijiang
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Zyryanka      RU  65.7500  150.8500     32.23        66          98
# 1    Cape Town      ZA -33.9258   18.4232     52.12        75          39
# 2  Port Alfred      ZA -33.5906   26.8910     53.17        65          87
# 3        Nalut      LY  30.3333   10.8500     70.38        37           0
# 4      Ushuaia      AR -54.8000  -68.3000     38.86        81          40
#
#    Wind Speed Current Description
# 0        9.31     overcast clouds
# 1        3.09    scattered clouds
# 2       19.22          light rain
# 3        8.68           clear sky
# 4        8.05    scattered clouds

# %%
# Create the output file (CSV).
output_data_file="WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
